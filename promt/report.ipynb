# %% [markdown]
# # Тут будут примеры с 1 промтом, и добавление 2-го бизнеса для УТП

# %% [markdown]
# ![image.png](attachment:image.png)
# *****
# [Промт](promts\dirt.txt)

# %% [markdown]
# Текста многовато, но логика лучше
# =======
# * ##### Для "слабых" моделей лучше представлять текст на том языке, на котором пишем промт
# ![image.png](attachment:image.png)
# ****
# [Промт](promts\sirt_for_lama.txt)

# %% [markdown]
# # Первые попытки в B2B

# %% [markdown]
# * В душе не чаю почему Llama поменяла Отправителя и Клиента местами.....
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ****
# [Промт](promts\first_AB.txt)

# %% [markdown]
# ## Сохраняет лимит в 100 слов, надо доработать с контактными данными
# ![image.png](attachment:image.png)
# ***
# [Промт](promts\second_AB.txt)

# %% [markdown]
# Появилась проблема.... ПРОМТ СЛИШКОМ БОЛЬШОЙ ДЛЯ GPT

# %% [markdown]
# Запрос сделан GPT-4
# ***
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ****
# [Промт](promts\TT.txt)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Поменяем роль что LLM является владельцем компании

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ***
# [Промт](promts\change_role.txt)
