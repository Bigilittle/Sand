# %% [markdown]
# ## Далее все запросы буду происходить по данному [промту](promt\promts\main.txt)

# %% [markdown]
# # GPT-4o
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # GPT-4mini
# ![image.png](attachment:image.png)

# %% [markdown]
# # Llama-3.1 8B (temp=0.8)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Mistral Large-2
# * ####  Пришлось добавить что бы не выделяла отедбные этапы в письме
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mistral Pixtral
# * ### По ощущениям немного тупее прошлой
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Arcee-SuperNova (на сайте, у них есть вроде api)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # SuperNova Q6_k_l
#
# * ### Плюсы: Модель умна и очень гибка. Под неё необходимо переписывать промт, но потенциально это лучший выбор
# * ### Минусы: потенциально самая медленная из представленных
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Yandex GPT (Pro)
# * ### Пользование моделью (api в том числе) платно, но у меня был спортивный интерес
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * #### Тут немного конечно грустно, но всё ещё не так плохо
# ![image.png](attachment:image.png)
